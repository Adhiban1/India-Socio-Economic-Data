# %%
from glob import glob
import pandas as pd

# %%
files = glob('dataset/*.csv')
files
# Out:
# ['dataset/gdp_Odisha1.csv',
#  'dataset/gdp_Haryana.csv',
#  'dataset/gdp_Punjab1.csv',
#  'dataset/gdp_Kerala1.csv',
#  'dataset/gdp_Maharashtra2.csv',
#  'dataset/gdp_AndhraPradesh1.csv',
#  'dataset/gdp_Bihar2.csv',
#  'dataset/gdp_WestBengal2.csv',
#  'dataset/gdp_Assam1.csv',
#  'dataset/gdp_Bihar1.csv',
#  'dataset/gdp_Karnataka2.csv',
#  'dataset/elementary_2015_16.csv',
#  'dataset/gdp_MadhyaPradesh.csv',
#  'dataset/gdp_Uttarakhand.csv',
#  'dataset/gdp_Tamilnadu.csv',
#  'dataset/gdp_Jharkhand.csv',
#  'dataset/gdp_Assam2.csv',
#  'dataset/gdp_AndhraPradesh2.csv',
#  'dataset/gdp_Maharashtra1.csv',
#  'dataset/gdp_Meghalaya.csv',
#  'dataset/gdp_UttarPradesh1.csv',
#  'dataset/gdp_Punjab2.csv',
#  'dataset/gdp_Kerala2.csv',
#  'dataset/gdp_HimachalPradesh.csv',
#  'dataset/gdp_Sikkim.csv',
#  'dataset/gdp_Chattisgarh.csv',
#  'dataset/gdp_Rajasthan1.csv',
#  'dataset/gdp_Rajasthan2.csv',
#  'dataset/gdp_UttarPradesh2.csv',
#  'dataset/gdp_Odisha2.csv',
# ...

# %%
len(files)
# Out:
# 37

# %%
dfs = [pd.read_csv(file) for file in files]

# %%
dfs[0]
# Out:
#        Year          Description        Angul     Balangir     Balasore  \
# 0   1999-00     GDP (in Rs. Cr.)  3360.520000  1416.820000  1814.500000
# 1   2000-01     GDP (in Rs. Cr.)  3314.310000  1263.150000  1938.160000
# 2   2001-02     GDP (in Rs. Cr.)  2997.570000  1441.840000  2019.010000
# 3   2002-03     GDP (in Rs. Cr.)  3515.410000  1348.020000  1928.330000
# 4   2003-04     GDP (in Rs. Cr.)  4181.100000  1622.460000  2231.140000
# 5   2004-05     GDP (in Rs. Cr.)  5155.140000  1759.490000  2550.150000
# 6   2005-06     GDP (in Rs. Cr.)  4463.820000  1863.680000  2710.640000
# 7   2006-07     GDP (in Rs. Cr.)  5139.910000  2102.260000  3124.380000
# 8   2000-01  Growth Rate % (YoY)    -1.375085   -10.846120     6.815101
# 9   2001-02  Growth Rate % (YoY)    -9.556740    14.146380     4.171482
# 10  2002-03  Growth Rate % (YoY)    17.275326    -6.506963    -4.491310
# 11  2003-04  Growth Rate % (YoY)    18.936340    20.358748    15.703225
# ...

# %%
dfs[0].columns
# Out:
# Index(['Year', 'Description', ' Angul', 'Balangir', ' Balasore', 'Bargarh',
#        'Baudh', 'Bhadrak', 'Cuttack', ' Deogarh', 'Dhenkanal', 'Gajapati',
#        'Ganjam', ' Jagatsinghpur', ' Jajpur', 'Jharsuguda', 'Kalahandi',
#        'Kandhamal', 'Kendrapara', 'Kendujhar', 'Khordha', 'Koraput',
#        'Malkangiri', 'Mayurbhanj', ' Nabarangpur', ' Nayargarh', 'Nuapada',
#        'Puri', 'Rayagada', 'Sambalpur', 'Sonapur', 'Sundargarh'],
#       dtype='object')
